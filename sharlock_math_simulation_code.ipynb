# %% [markdown]
# <a href="https://colab.research.google.com/github/debashisdotchatterjee/holmes_backward_simulation1/blob/main/sharlock_math_simulation_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -r requirements.txt
# !python holmes_backward_simulation.py
# Out:
# ...
# Figure(1250x480)
# Figure(700x550)
# Figure(1000x520)
# Figure(680x530)
# Figure(840x620)
# Figure(720x500)
#
# === PERFORMANCE SUMMARY ===
#                     metric    value
#           planner_accuracy 0.902000
#              top2_accuracy 0.993333
#        multiclass_log_loss 0.210110
#     multiclass_brier_score 0.132119
# mean_prediction_confidence 0.904269
#
# === CONFUSION MATRIX ===
#                        pred_outsider_gambler  pred_trainer  pred_rival_trainer  pred_unknown_intruder
# true_outsider_gambler                    268             0                  10                     35
# true_trainer                               0           731                   0                      0
# true_rival_trainer                         5             0                 274                      0
# true_unknown_intruder                     93             0                   4                     80
#
# === CLUE IMPORTANCE ===
# ...
